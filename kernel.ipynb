# %%
! pip install opencv-python scikit-image
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.8/14.8 MB 77.6 kB/s eta 0:00:0000:0100:06
# ...
#   Using cached pillow-11.1.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.5 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 315.8/315.8 KB 61.0 kB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.6/227.6 KB 58.2 kB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 81.6 kB/s eta 0:00:0000:0100:01
# ...

# %%
from skimage import data
import matplotlib.pyplot as plt
import cv2

# %%
image = data.coffee()

# %%
image.shape
# Out:
# (400, 600, 3)

# %%
plt.figure(figsize=(5,5))
plt.imshow(image)
plt.axis('off')
# Out:
# (-0.5, 599.5, 399.5, -0.5)

# %%
import numpy as np
kernel = np.array([[0,-1,0],
                   [-1,5,-1],
                   [0,-1,0]])

# %%
convolved_img=cv2.filter2D(image,-1,kernel)

# %%
fig,ax=plt.subplots(1,2,figsize=(16,32))
ax[0].imshow(image)
ax[0].axis('off')
ax[0].set_title('original')

ax[1].imshow(convolved_img)
ax[1].axis('off')
ax[1].set_title('sharpen')
# Out:
# Text(0.5, 1.0, 'sharpen')

# %%
kernel=np.array([[0.0625,0.125,0.0625],
                 [0.125,0.25,0.125],
                 [0.0625,0.125,0.0625]])

# %%
convolved_img=cv2.filter2D(image,-1,kernel)
fig,ax=plt.subplots(1,2,figsize=(16,32))
ax[0].imshow(image)
ax[0].axis('off')
ax[0].set_title('original')

ax[1].imshow(convolved_img)
ax[1].axis('off')
ax[1].set_title('blurred')
# Out:
# Text(0.5, 1.0, 'blurred')
